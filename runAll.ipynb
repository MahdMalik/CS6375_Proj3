# %%
from mlp import MLP_Manager
from cnn import CNN_Manager

datasetTypes = ["mnist", "cifar"]

mlpModel = MLP_Manager()

cnnModel = CNN_Manager()

for dataset in datasetTypes:
    mlpModel.doFullTuning(dataset, "MLP")
    mlpModel.doFinalEvaluation(dataset, "MLP")

for dataset in datasetTypes:
    cnnModel.createFullModel(dataset, "CNN")
    mlpModel.doFullTuning(dataset, "CNN")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 11
#       8 cnnModel = CNN_Manager()
#      10 for dataset in datasetTypes:
# ---> 11     mlpModel.doFullTuning(dataset, "MLP")
#      12     mlpModel.doFinalEvaluation(dataset)
#      14 for dataset in datasetTypes:
#
# File c:\Users\mahd\Documents\CS 6375\model.py:121, in Model.doFullTuning(self, dataset, modelName)
#     118 self.createBatches(sampledParams["batchSize"], dataset, False)
#     120 # train and valuate this current model, get accuracy
# --> 121 accuracy = self.currentModel.trainAndEvaluate(self.trainBatch, self.testBatch, False, self.device)
#     123 # keep the parameter set with the highest scores
#     124 if(accuracy > highestAccuracy):
#
# File c:\Users\mahd\Documents\CS 6375\mlp.py:135, in MLP.trainAndEvaluate(self, trainSet, testSet, finalTrain, device)
# ...
